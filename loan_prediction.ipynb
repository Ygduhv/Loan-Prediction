# %%
# Importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt  #visualization
import seaborn as sns  #visualization
# %matplotlib inline
from sklearn.model_selection import train_test_split

# %%
# Importing the dataset
data = pd.read_csv('loan_borowwer_data.csv')

# %%
data
# Out:
#       credit.policy             purpose  int.rate  installment  \
# 0                 1  debt_consolidation    0.1189       829.10
# 1                 1         credit_card    0.1071       228.22
# 2                 1  debt_consolidation    0.1357       366.86
# 3                 1  debt_consolidation    0.1008       162.34
# 4                 1         credit_card    0.1426       102.92
# ...             ...                 ...       ...          ...
# 9573              0           all_other    0.1461       344.76
# 9574              0           all_other    0.1253       257.70
# 9575              0  debt_consolidation    0.1071        97.81
# 9576              0    home_improvement    0.1600       351.58
# 9577              0  debt_consolidation    0.1392       853.43
#
#       log.annual.inc    dti  fico  days.with.cr.line  revol.bal  revol.util  \
# 0          11.350407  19.48   737        5639.958333      28854        52.1
# ...

# %%
data.shape
# Out:
# (9578, 14)

# %%
data.head()
# Out:
#    credit.policy             purpose  int.rate  installment  log.annual.inc  \
# 0              1  debt_consolidation    0.1189       829.10       11.350407
# 1              1         credit_card    0.1071       228.22       11.082143
# 2              1  debt_consolidation    0.1357       366.86       10.373491
# 3              1  debt_consolidation    0.1008       162.34       11.350407
# 4              1         credit_card    0.1426       102.92       11.299732
#
#      dti  fico  days.with.cr.line  revol.bal  revol.util  inq.last.6mths  \
# 0  19.48   737        5639.958333      28854        52.1               0
# 1  14.29   707        2760.000000      33623        76.7               0
# 2  11.63   682        4710.000000       3511        25.6               1
# 3   8.10   712        2699.958333      33667        73.2               1
# 4  14.97   667        4066.000000       4740        39.5               0
#
#    delinq.2yrs  pub.rec  not.fully.paid
# ...

# %%
data.tail()
# Out:
#       credit.policy             purpose  int.rate  installment  \
# 9573              0           all_other    0.1461       344.76
# 9574              0           all_other    0.1253       257.70
# 9575              0  debt_consolidation    0.1071        97.81
# 9576              0    home_improvement    0.1600       351.58
# 9577              0  debt_consolidation    0.1392       853.43
#
#       log.annual.inc    dti  fico  days.with.cr.line  revol.bal  revol.util  \
# 9573       12.180755  10.39   672       10474.000000     215372        82.1
# 9574       11.141862   0.21   722        4380.000000        184         1.1
# 9575       10.596635  13.09   687        3450.041667      10036        82.9
# 9576       10.819778  19.18   692        1800.000000          0         3.2
# 9577       11.264464  16.28   732        4740.000000      37879        57.0
#
#       inq.last.6mths  delinq.2yrs  pub.rec  not.fully.paid
# 9573               2            0        0               1
# ...

# %%
data.isnull().sum()
# Out:
# credit.policy        0
# purpose              0
# int.rate             0
# installment          0
# log.annual.inc       0
# dti                  0
# fico                 0
# days.with.cr.line    0
# revol.bal            0
# revol.util           0
# inq.last.6mths       0
# delinq.2yrs          0
# pub.rec              0
# not.fully.paid       0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9578 entries, 0 to 9577
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   credit.policy      9578 non-null   int64
#  1   purpose            9578 non-null   object
#  2   int.rate           9578 non-null   float64
#  3   installment        9578 non-null   float64
#  4   log.annual.inc     9578 non-null   float64
#  5   dti                9578 non-null   float64
#  6   fico               9578 non-null   int64
#  7   days.with.cr.line  9578 non-null   float64
#  8   revol.bal          9578 non-null   int64
#  9   revol.util         9578 non-null   float64
#  10  inq.last.6mths     9578 non-null   int64
#  11  delinq.2yrs        9578 non-null   int64
#  12  pub.rec            9578 non-null   int64
#  13  not.fully.paid     9578 non-null   int64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 1.0+ MB

# %%
data.describe()
# Out:
#        credit.policy     int.rate  installment  log.annual.inc          dti  \
# count    9578.000000  9578.000000  9578.000000     9578.000000  9578.000000
# mean        0.804970     0.122640   319.089413       10.932117    12.606679
# std         0.396245     0.026847   207.071301        0.614813     6.883970
# min         0.000000     0.060000    15.670000        7.547502     0.000000
# 25%         1.000000     0.103900   163.770000       10.558414     7.212500
# 50%         1.000000     0.122100   268.950000       10.928884    12.665000
# 75%         1.000000     0.140700   432.762500       11.291293    17.950000
# max         1.000000     0.216400   940.140000       14.528354    29.960000
#
#               fico  days.with.cr.line     revol.bal   revol.util  \
# count  9578.000000        9578.000000  9.578000e+03  9578.000000
# mean    710.846314        4560.767197  1.691396e+04    46.799236
# std      37.970537        2496.930377  3.375619e+04    29.014417
# ...

# %%
data.describe(include='object')
# Out:
#                    purpose
# count                 9578
# unique                   7
# top     debt_consolidation
# freq                  3957

# %%
data['purpose'].value_counts()  #rows
# Out:
# debt_consolidation    3957
# all_other             2331
# credit_card           1262
# home_improvement       629
# small_business         619
# major_purchase         437
# educational            343
# Name: purpose, dtype: int64

# %%
data.columns
# Out:
# Index(['credit.policy', 'purpose', 'int.rate', 'installment', 'log.annual.inc',
#        'dti', 'fico', 'days.with.cr.line', 'revol.bal', 'revol.util',
#        'inq.last.6mths', 'delinq.2yrs', 'pub.rec', 'not.fully.paid'],
#       dtype='object')

# %%
data['credit.policy'].value_counts()
# credit.policy: 1 if the customer meets 
# the credit underwriting criteria
# of LendingClub.com, and 0 otherwise.
# Out:
# 1    7710
# 0    1868
# Name: credit.policy, dtype: int64

# %%
# interest rate 
sns.displot(data['int.rate'])  #increse means risky people

# %%
sns.displot(data['int.rate'])

# %%
data.corr()
# Out:
# C:\Users\atiks\AppData\Local\Temp\ipykernel_2272\2627137660.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()
#                    credit.policy  int.rate  installment  log.annual.inc  \
# credit.policy           1.000000 -0.294089     0.058770        0.034906
# int.rate               -0.294089  1.000000     0.276140        0.056383
# installment             0.058770  0.276140     1.000000        0.448102
# log.annual.inc          0.034906  0.056383     0.448102        1.000000
# dti                    -0.090901  0.220006     0.050202       -0.054065
# fico                    0.348319 -0.714821     0.086039        0.114576
# days.with.cr.line       0.099026 -0.124022     0.183297        0.336896
# revol.bal              -0.187518  0.092527     0.233625        0.372140
# ...

# %%
data.corr(numeric_only=True)
# Out:
#                    credit.policy  int.rate  installment  log.annual.inc  \
# credit.policy           1.000000 -0.294089     0.058770        0.034906
# int.rate               -0.294089  1.000000     0.276140        0.056383
# installment             0.058770  0.276140     1.000000        0.448102
# log.annual.inc          0.034906  0.056383     0.448102        1.000000
# dti                    -0.090901  0.220006     0.050202       -0.054065
# fico                    0.348319 -0.714821     0.086039        0.114576
# days.with.cr.line       0.099026 -0.124022     0.183297        0.336896
# revol.bal              -0.187518  0.092527     0.233625        0.372140
# revol.util             -0.104095  0.464837     0.081356        0.054881
# inq.last.6mths         -0.535511  0.202780    -0.010419        0.029171
# delinq.2yrs            -0.076318  0.156079    -0.004368        0.029203
# pub.rec                -0.054243  0.098162    -0.032760        0.016506
# ...

# %%
plt.figure(figsize=(10,7))
sns.heatmap(data.corr(numeric_only=True),annot=True) #annot for values
# Out:
# <Axes: >

# %%
sns.boxplot(data['fico'])
# Out:
# <Axes: >

# %%
data['not.fully.paid'].value_counts()
# 0: paid the loan 
# 1: not fully paid
# Out:
# 0    8045
# 1    1533
# Name: not.fully.paid, dtype: int64

# %%
plt.figure(figsize=(15,7))
sns.countplot(x=data['purpose'],data=data)  #x and y is parameters of count
# hue : (optional) This parameter take column name for colour encoding.
# Out:
# <Axes: xlabel='purpose', ylabel='count'>

# %%
plt.figure(figsize=(15,7))
sns.countplot(x=data['purpose'], hue='not.fully.paid',data=data)
# hue : (optional) This parameter take column name for colour encoding.
# Out:
# <Axes: xlabel='purpose', ylabel='count'>

# %%
data.shape
# Out:
# (9578, 14)

# %%
data['fico'].hist()
# Out:
# <Axes: >

# %%
data['fico'].hist(bins=30)
# Out:
# <Axes: >

# %%
data['purpose'].value_counts()
# Out:
# debt_consolidation    3957
# all_other             2331
# credit_card           1262
# home_improvement       629
# small_business         619
# major_purchase         437
# educational            343
# Name: purpose, dtype: int64

# %%
data
# Out:
#       credit.policy             purpose  int.rate  installment  \
# 0                 1  debt_consolidation    0.1189       829.10
# 1                 1         credit_card    0.1071       228.22
# 2                 1  debt_consolidation    0.1357       366.86
# 3                 1  debt_consolidation    0.1008       162.34
# 4                 1         credit_card    0.1426       102.92
# ...             ...                 ...       ...          ...
# 9573              0           all_other    0.1461       344.76
# 9574              0           all_other    0.1253       257.70
# 9575              0  debt_consolidation    0.1071        97.81
# 9576              0    home_improvement    0.1600       351.58
# 9577              0  debt_consolidation    0.1392       853.43
#
#       log.annual.inc    dti  fico  days.with.cr.line  revol.bal  revol.util  \
# 0          11.350407  19.48   737        5639.958333      28854        52.1
# ...

# %%
# Apply dummy encoding on purpose column
df=pd.get_dummies(data,columns=['purpose'],drop_first=True)  #data is name of dataframe

# %%
df
# Out:
#       credit.policy  int.rate  installment  log.annual.inc    dti  fico  \
# 0                 1    0.1189       829.10       11.350407  19.48   737
# 1                 1    0.1071       228.22       11.082143  14.29   707
# 2                 1    0.1357       366.86       10.373491  11.63   682
# 3                 1    0.1008       162.34       11.350407   8.10   712
# 4                 1    0.1426       102.92       11.299732  14.97   667
# ...             ...       ...          ...             ...    ...   ...
# 9573              0    0.1461       344.76       12.180755  10.39   672
# 9574              0    0.1253       257.70       11.141862   0.21   722
# 9575              0    0.1071        97.81       10.596635  13.09   687
# 9576              0    0.1600       351.58       10.819778  19.18   692
# 9577              0    0.1392       853.43       11.264464  16.28   732
#
#       days.with.cr.line  revol.bal  revol.util  inq.last.6mths  delinq.2yrs  \
# ...

# %%
df.shape
# Out:
# (9578, 19)

# %%
data.loc[9574]
# Out:
# credit.policy                0
# purpose              all_other
# int.rate                0.1253
# installment              257.7
# log.annual.inc       11.141862
# dti                       0.21
# fico                       722
# days.with.cr.line       4380.0
# revol.bal                  184
# revol.util                 1.1
# inq.last.6mths               5
# delinq.2yrs                  0
# pub.rec                      0
# not.fully.paid               1
# Name: 9574, dtype: object

# %%
df.columns
# Out:
# Index(['credit.policy', 'int.rate', 'installment', 'log.annual.inc', 'dti',
#        'fico', 'days.with.cr.line', 'revol.bal', 'revol.util',
#        'inq.last.6mths', 'delinq.2yrs', 'pub.rec', 'not.fully.paid',
#        'purpose_credit_card', 'purpose_debt_consolidation',
#        'purpose_educational', 'purpose_home_improvement',
#        'purpose_major_purchase', 'purpose_small_business'],
#       dtype='object')

# %%
X=df.drop('not.fully.paid', axis=1)
y=df['not.fully.paid']

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=0)

# %%
X_train
# Out:
#       credit.policy  int.rate  installment  log.annual.inc    dti  fico  \
# 872               1    0.0768       155.95       10.596635  11.49   797
# 4184              1    0.1287        94.18       10.721614   3.52   682
# 3170              1    0.1189       505.76       11.407565   9.44   737
# 4677              1    0.1114       360.84       10.757733  10.39   722
# 4884              1    0.1218       149.85       11.338572   0.07   707
# ...             ...       ...          ...             ...    ...   ...
# 7891              0    0.1754       376.29       10.341742  22.37   642
# 9225              0    0.1253       669.33       11.034890   6.89   732
# 4859              1    0.1774       720.42       11.243319   7.04   702
# 3264              1    0.1284       403.42       11.561716   9.77   687
# 2732              1    0.1221       399.78       11.002100  16.16   742
#
#       days.with.cr.line  revol.bal  revol.util  inq.last.6mths  delinq.2yrs  \
# ...

# %%
X_train.shape
# Out:
# (6704, 18)

# %%
from sklearn.tree import DecisionTreeClassifier
dtree=DecisionTreeClassifier()
dtree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
X_test
# Out:
#       credit.policy  int.rate  installment  log.annual.inc    dti  fico  \
# 3343              1    0.1189        49.75       10.829729  16.87   687
# 9                 1    0.1221        84.12       10.203592  10.00   707
# 1741              1    0.1695       712.54       11.918391  13.61   672
# 5160              1    0.1739       286.78       11.189962  19.59   667
# 7760              0    0.1312       202.51        9.392662   4.40   657
# ...             ...       ...          ...             ...    ...   ...
# 6523              1    0.0774       636.86       11.225243  15.38   707
# 6920              1    0.1739       896.19       11.849398   2.47   747
# 8575              0    0.1576       148.04       10.819778  21.50   652
# 4528              1    0.1461       330.97       10.645425  15.09   672
# 4731              1    0.2017       186.26       10.819778   6.00   672
#
#       days.with.cr.line  revol.bal  revol.util  inq.last.6mths  delinq.2yrs  \
# ...

# %%
y_pred=dtree.predict(X_test)

# %%
y_pred.shape
# Out:
# (2874,)

# %%
y_pred
# Out:
# array([1, 0, 0, ..., 0, 0, 1], dtype=int64)

# %%
from sklearn.metrics import classification_report,confusion_matrix
print(confusion_matrix(y_test,y_pred))
# Out:
# [[2007  399]
#  [ 350  118]]

# %%
tn, fp, fn, tp = confusion_matrix(y_test, y_pred).ravel()

# %%
print(tn,fp,fn,tp)
# Out:
# 2007 399 350 118

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test,y_pred))
# Out:
# 0.7393876130828114

# %%
from sklearn.tree import DecisionTreeClassifier
dtree1 = DecisionTreeClassifier(criterion='entropy')
dtree1.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
y_pred=dtree1.predict(X_test)

# %%
print(accuracy_score(y_test,y_pred))
# Out:
# 0.7289491997216423

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid={'max_depth':[2,3,4,5],
           'max_features':[1,3,5,10],
           'min_samples_split':[2,3,5,10],
           'criterion':['gini','entropy'],
           'min_samples_leaf':[1,2,3,4]
           }
grid=GridSearchCV(dtree, param_grid, verbose=2)
grid.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 512 candidates, totalling 2560 fits
# [CV] END criterion=gini, max_depth=2, max_features=1, min_samples_leaf=1, min_samples_split=2; total time=   0.0s
# [CV] END criterion=gini, max_depth=2, max_features=1, min_samples_leaf=1, min_samples_split=2; total time=   0.0s
# [CV] END criterion=gini, max_depth=2, max_features=1, min_samples_leaf=1, min_samples_split=2; total time=   0.0s
# [CV] END criterion=gini, max_depth=2, max_features=1, min_samples_leaf=1, min_samples_split=2; total time=   0.0s
# [CV] END criterion=gini, max_depth=2, max_features=1, min_samples_leaf=1, min_samples_split=2; total time=   0.0s
# [CV] END criterion=gini, max_depth=2, max_features=1, min_samples_leaf=1, min_samples_split=3; total time=   0.0s
# [CV] END criterion=gini, max_depth=2, max_features=1, min_samples_leaf=1, min_samples_split=3; total time=   0.0s
# [CV] END criterion=gini, max_depth=2, max_features=1, min_samples_leaf=1, min_samples_split=3; total time=   0.0s
# ...

# %%
# Pass parameter as a dictionary 
param_grid={'max_depth':[2,3,4,5], #hyperparameters
           'max_features':[1,3,5,10],
           'min_samples_split':[2,3,5,10],
           'criterion':['gini','entropy'],
           'min_samples_leaf':[1,2,3,4]
           }
# Make the object of the class GridSearchCV
grid=GridSearchCV(dtree,param_grid,verbose=0)
grid.fit(X_train,y_train)
# Out:
# GridSearchCV(estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [2, 3, 4, 5],
#                          'max_features': [1, 3, 5, 10],
#                          'min_samples_leaf': [1, 2, 3, 4],
#                          'min_samples_split': [2, 3, 5, 10]})

# %%
grid.best_params_
# Out:
# {'criterion': 'entropy',
#  'max_depth': 2,
#  'max_features': 5,
#  'min_samples_leaf': 3,
#  'min_samples_split': 2}

# %%
# Train decision tree 
from sklearn.tree import DecisionTreeClassifier
dtree21=DecisionTreeClassifier(criterion='entropy',
                               max_depth= 3,
                               max_features= 1,
                               min_samples_leaf=1,
                               min_samples_split= 3)
dtree21.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=3, max_features=1,
#                        min_samples_split=3)

# %%
y_pred=dtree21.predict(X_test)

# %%
# Accuracy 
from sklearn.metrics import accuracy_score  #accuracy is good in hyperparameter
print(accuracy_score(y_test, y_pred))
# Out:
# 0.837160751565762

# %%
# Accuracy 
y_pred=dtree.predict(X_test)
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test, y_pred))
# Out:
# 0.7393876130828114

# %%
# Accuracy 
from sklearn.metrics import confusion_matrix
print(confusion_matrix(y_test, y_pred))
# Out:
# [[2007  399]
#  [ 350  118]]

# %%
# Accuracy 
from sklearn.metrics import precision_score
print(precision_score(y_test, y_pred))
# Out:
# 0.22823984526112184

# %%
# Accuracy 
from sklearn.metrics import recall_score
print(recall_score(y_test, y_pred))
# Out:
# 0.25213675213675213

# %%
# Accuracy 
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.83      0.84      2406
#            1       0.23      0.25      0.24       468
#
#     accuracy                           0.74      2874
#    macro avg       0.54      0.54      0.54      2874
# weighted avg       0.75      0.74      0.74      2874
